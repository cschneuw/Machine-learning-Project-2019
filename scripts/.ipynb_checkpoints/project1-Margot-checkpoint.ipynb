# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load the training data into feature matrix, class labels, and event ids:

# %%
from proj1_helpers import *
import os
data_base_path = os.path.join(os.pardir, 'data')
data_folder = 'train.csv'
data_path = os.path.join(data_base_path, data_folder)
y, tX, ids = load_csv_data(data_path)

# %% [markdown]
# ### Change later : Simple data description
# - all variables are floating point, except PRI_jet_num which is integer
# - variables prefixed with PRI (for PRImitives) are “raw” quantities about the bunch collision as measured by the detector.
# - variables prefixed with DER (for DERived) are quantities computed from the primitive features, which were selected by the physicists of ATLAS.
# - it can happen that for some entries some variables are meaningless or cannot be computed; in this case, their value is −999.0, which is outside the normal range of all variables.

# %%
print('y shape = ' + str(y.shape) + '\ntX shape =' + str(tX.shape) + '\nids shape = ' + str(ids.shape))

# %% [markdown]
# Description of the data:
# - `y` (N) is composed of the labels (-1 or 1) of all the samples.
# - `tX` (N x F) is composed of the values of the features (F) for all samples (N)
# - `ids` (N) is composed of all the index (100000-349999) of the samples (N)
#
# Moreover, the number of features is 30 (F=30) and the number of samples is 250'000 (N=250'000).

# %%
tX.shape[0]

# %%
# putting the meaningless values to 0 to show clearer graphs
tX0 = np.where(tX==-999, np.nan,tX) #nanmin nanstd

# %%
def plot_feature(ids, tX0, y, f):
    fig, ax = plt.subplots(1, 2, figsize=(12, 12))
    
    col = np.where(y==1, 'r', 'b')
    ax[1].scatter(ids, tX0[:,f], c=col)
    ax[1].set_title('Values of feature {} regarding the sample'.format(f))
    ax[1].xlabel('Samples')
    ax[1].ylabel('Values')
    #ax[0] = plt.scatter(ids, tX0[:,f], c=col)
    #ax[0] = plt.title('Values of feature {} regarding the sample'.format(f))
    #ax[0] = plt.xlabel('Samples')
    #ax[0] = plt.ylabel('Values')
    
    
    bins = 20
    #ax[1] = plt.hist(tX0[:,f], bins)
    #ax[1] = plt.title("Histogram of factor {} distribution".format(f))
    #ax[1] = plt.xlabel('Values of the factor {}'.format(f))
    #ax[1] = plt.ylabel('Number of apparitions')
    
    
    
    #plt.scatter(ids, tX0[:,f], c=col)
    #plt.xlabel('Samples')
    #plt.ylabel('Values')
    
    #ax[1].imshow(brain_im, cmap='gray')
    #ax[1].set_title('MRI brain image ({} px, {} px)'.format(im_h, im_w))
    #ax[1].axis('off')
    
    plt.show()

# %%
plot_feature(ids, tX0, y, 12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f8b31190caa6> in <module>
# ----> 1 plot_feature(ids, tX0, y, 12)
#
# <ipython-input-20-037898e554fe> in plot_feature(ids, tX0, y, f)
#       5     ax[1].scatter(ids, tX0[:,f], c=col)
#       6     ax[1].set_title('Values of feature {} regarding the sample'.format(f))
# ----> 7     ax[1].xlabel('Samples')
#       8     ax[1].ylabel('Values')
#       9     #ax[0] = plt.scatter(ids, tX0[:,f], c=col)
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlabel'

# %%
f = 13 # index of feature
col = np.where(y==1, 'r', 'b')
plt.scatter(ids, tX0[:,f], c=col)
plt.title('Values of feature {} regarding the sample'.format(f))
plt.xlabel('Samples')
plt.ylabel('Values')

# %%
f = 29
bins = 20
plt.hist(tX0[:,f], bins)
plt.title("Histogram of factor {} distribution".format(f))
plt.xlabel('Values of the factor {}'.format(f))
plt.ylabel('Number of apparitions')

# %% [markdown]
# ## Do your thing crazy machine learning thing here :) ...

# %% [markdown]
# ## Generate predictions and save ouput in csv format for submission:

# %%
DATA_TEST_PATH = '' # TODO: download train data and supply path here 
_, tX_test, ids_test = load_csv_data(DATA_TEST_PATH)

# %%
OUTPUT_PATH = '' # TODO: fill in desired name of output file for submission
y_pred = predict_labels(weights, tX_test)
create_csv_submission(ids_test, y_pred, OUTPUT_PATH)
